# %%
import pixiedust
# Out:
#         <div style="margin:10px">
#             <a href="https://github.com/ibm-watson-data-lab/pixiedust" target="_new">
#                 <img src="https://github.com/ibm-watson-data-lab/pixiedust/raw/master/docs/_static/pd_icon32.png" style="float:left;margin-right:10px"/>
#             </a>
#             <span>Pixiedust version 1.1.15</span>
#         </div>
# Pixiedust database opened successfully

# %%
# %env HARDWAREUMAPS=/ds/hardwareumaps
print(os.getenv('HARDWAREUMAPS'))
# Out:
# env: HARDWAREUMAPS=/ds/hardwareumaps
# /ds/hardwareumaps

# %%
from respet.recon.reconstruction import Reconstruction

# %%
loc = '/ds/HYGLY30/V2/Twilite_V2-Converted'

# %%
obj = Reconstruction(loc, ac=True, v=True)
# Out:
# --------------------------------------------------------------------------
# i> file: /ds/HYGLY30/V2/Twilite_V2-Converted-AC/output/1.3.12.2_createStaticUTE.nii.gz
# --------------------------------------------------------------------------
# i> file: /ds/HYGLY30/V2/Twilite_V2-Converted-AC/umap/HYGLY30V2_TWILITE.MR.CCIR-00700_CCIR-00754_Arbelaez.13.65.20161028.140708.1i41dix.dcm
#    Image Type: ['DERIVED', 'PRIMARY', 'M', 'NORM', 'DIS3D', 'DIS2D', 'MRPET_UMAP3D']
#    Comments: MR based umap
#    TR: 3.6
#    TE: 2.46
#
# --------------------------------------------------------------------------
# i> file: /ds/HYGLY30/V2/Twilite_V2-Converted-AC/umap/HYGLY30V2_TWILITE.MR.CCIR-00700_CCIR-00754_Arbelaez.13.89.20161028.140708.1ax5hwq.dcm
#    Image Type: ['DERIVED', 'PRIMARY', 'M', 'NORM', 'DIS3D', 'DIS2D', 'MRPET_UMAP3D']
#    Comments: MR based umap
#    TR: 3.6
#    TE: 2.46
#
# --------------------------------------------------------------------------
# ...

# %%
sta = obj.createStaticUTE(fcomment='_createStaticUTE')
# Out:
# i> gantry offset: [ 0.09893863  0.00415111 -0.87810154]
# i> table position origin: [-1160.     0.     0.]
# i> got LM interfile.
# i> got CSA info.
# i> loaded hardware mu-map from file: /ds/hardwareumaps/hmumap.npy
# i> histograming with span 11 and 1 dynamic frames.
# i> duration by integrating time tags [s]: 301
# i> centre of mass of axial radiodistribution (filtered with Gaussian of SD = 5 ):  COMPLETED.
# i> dynamic and static buckets single rates:  COMPLETED.
# /opt/conda/lib/python2.7/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# i> gantry offset: [ 0.09893863  0.00415111 -0.87810154]
# i> table position origin: [-1160.     0.     0.]
# i> got LM interfile.
# i> got CSA info.
# i> histograming with span 11 and 1 dynamic frames.
# ...
